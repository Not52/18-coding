# %% [markdown]
# <a href="https://colab.research.google.com/github/Not52/18-coding/blob/main/midParinya(not).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = float(input("ป้อนจำนวนจริงตัวที่ 1: "))
num2 = float(input("ป้อนจำนวนจริงตัวที่ 2: "))
num3 = float(input("ป้อนจำนวนจริงตัวที่ 3: "))

sum_of_two = num1 + num2

if sum_of_two > num3:
    print("a + b > c")
# Out:
# ป้อนจำนวนจริงตัวที่ 1: 1
# ป้อนจำนวนจริงตัวที่ 2: 2
# ป้อนจำนวนจริงตัวที่ 3: 12
